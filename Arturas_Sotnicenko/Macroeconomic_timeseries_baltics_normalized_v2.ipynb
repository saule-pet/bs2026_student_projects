# %% [markdown]
# This mirrored notebook keeps the visible normalization workflow in notebook cells, but now runs the typed `macro_indicator_v2` country pipeline so the notebook renders from real country data without the legacy notebook-helper surface.

# %%
from __future__ import annotations

import sys
from pathlib import Path

project_root = Path.cwd().resolve()
for candidate in (project_root, *project_root.parents):
    if (candidate / "macro_indicator_v2").exists():
        project_root = candidate
        break
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from macro_indicator_v2.infrastructure.notebook import (
    render_real_country_notebook_section,
    resolve_project_root,
)

# %%
project_root = resolve_project_root()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

project_subdir = project_root / "bs2026_student_projects" / "Arturas_Sotnicenko_v2"
source_output_root = project_subdir / "outputs_baltics_v2"
country_codes = ("LT", "LV", "EE")

# %%
indicator_groups = {
    "Output and growth": ["real_gdp", "gdp_current_usd", "gdp_per_capita"],
    "Inflation and prices": ["inflation_cpi_yoy"],
    "Fiscal indicators": ["general_government_gross_debt_pct_gdp"],
}
normalized_region_label = "Baltics_v2"
normalization_config = None
force_zscore_refresh = False

# normalization_config = {
#     "mode": "rolling_trailing",
#     "rolling_window_years": 10,
#     "exclude_current_from_window": True,
#     "min_obs_for_zscore": 5,
# }

print(f"Dynamic normalization enabled: {normalization_config is not None}")
print(f"Force refresh: {force_zscore_refresh}")
# Out:
# Dynamic normalization enabled: False
# Force refresh: False

# %%
def _render_country_normalized_section(
    country_code: str,
    *,
    normalization_config=normalization_config,
    region_label=normalized_region_label,
    force_refresh=force_zscore_refresh,
    show_labels: bool = False,
):
    run = render_real_country_notebook_section(
        country_code=country_code,
        country_output_dir=source_output_root / country_code,
        normalization_config=normalization_config,
        region_label=region_label,
        force_refresh=force_refresh,
        indicator_groups=indicator_groups,
        project_root=project_root,
        include_analysis=True,
        reuse_existing=not force_refresh,
        show_sections=True,
        show_manifest=True,
        show_labels=show_labels,
        show_visuals=True,
    )
    return run.notebook_view

# %% [markdown]
# This section keeps the baseline normalized notebook shape, but now it runs the explicit-country typed pipeline for each country output root. Use the override example below when you want a fresh rerender with a different normalization policy.

# %%
_lt_baseline_view = _render_country_normalized_section("LT")
_lv_baseline_view = _render_country_normalized_section("LV")
_ee_baseline_view = _render_country_normalized_section("EE")
# Out:
# ### Lithuania
# - Render: Lithuania | baseline static | region Baltics_v2
# - Normalization: Static baseline from 1999, min obs 3
# - Transformation: No transformation requested.
#   country_code country_display_name    render_origin region_label  \
# 0           LT            Lithuania  baseline_static   Baltics_v2
#
#                           normalization                transformation  \
# 0  Static baseline from 1999, min obs 3  No transformation requested.
#
#                                        manifest_path  \
# 0  /workspaces/da-ai-v2/bs2026_student_projects/A...
#
#                                       anomalies_path
# 0  /workspaces/da-ai-v2/bs2026_student_projects/A...
# #### Indicator sections
#              group_name                                      indicator_ids
# 0     Fiscal indicators              general_government_gross_debt_pct_gdp
# 1  Inflation and prices                                  inflation_cpi_yoy
# 2     Output and growth          real_gdp, gdp_current_usd, gdp_per_capita
# 3             Remaining  exchange_rate_lcu_per_usd, general_government_...
# #### Chart artifacts
# _Missing zscore_heatmap: /workspaces/da-ai-v2/bs2026_student_projects/Arturas_Sotnicenko_v2/outputs_baltics_v2/LT/charts/zscore_normalization_heatmap.png_
# _Missing zscore_timelines: /workspaces/da-ai-v2/bs2026_student_projects/Arturas_Sotnicenko_v2/outputs_baltics_v2/LT/charts/zscore_normalization_timelines.png_
# ### Latvia
# - Render: Latvia | baseline static | region Baltics_v2
# - Normalization: Static baseline from 1999, min obs 3
# - Transformation: No transformation requested.
#   country_code country_display_name    render_origin region_label  \
# 0           LV               Latvia  baseline_static   Baltics_v2
#
#                           normalization                transformation  \
# 0  Static baseline from 1999, min obs 3  No transformation requested.
#
#                                        manifest_path  \
# 0  /workspaces/da-ai-v2/bs2026_student_projects/A...
#
#                                       anomalies_path
# 0  /workspaces/da-ai-v2/bs2026_student_projects/A...
# #### Indicator sections
#              group_name                                      indicator_ids
# 0     Fiscal indicators              general_government_gross_debt_pct_gdp
# 1  Inflation and prices                                  inflation_cpi_yoy
# 2     Output and growth          real_gdp, gdp_current_usd, gdp_per_capita
# 3             Remaining  exchange_rate_lcu_per_usd, general_government_...
# #### Chart artifacts
# _Missing zscore_heatmap: /workspaces/da-ai-v2/bs2026_student_projects/Arturas_Sotnicenko_v2/outputs_baltics_v2/LV/charts/zscore_normalization_heatmap.png_
# _Missing zscore_timelines: /workspaces/da-ai-v2/bs2026_student_projects/Arturas_Sotnicenko_v2/outputs_baltics_v2/LV/charts/zscore_normalization_timelines.png_
# ### Estonia
# - Render: Estonia | baseline static | region Baltics_v2
# - Normalization: Static baseline from 1999, min obs 3
# - Transformation: No transformation requested.
#   country_code country_display_name    render_origin region_label  \
# 0           EE              Estonia  baseline_static   Baltics_v2
#
#                           normalization                transformation  \
# 0  Static baseline from 1999, min obs 3  No transformation requested.
#
#                                        manifest_path  \
# 0  /workspaces/da-ai-v2/bs2026_student_projects/A...
#
#                                       anomalies_path
# 0  /workspaces/da-ai-v2/bs2026_student_projects/A...
# #### Indicator sections
#              group_name                                      indicator_ids
# 0     Fiscal indicators              general_government_gross_debt_pct_gdp
# 1  Inflation and prices                                  inflation_cpi_yoy
# 2     Output and growth          real_gdp, gdp_current_usd, gdp_per_capita
# 3             Remaining  exchange_rate_lcu_per_usd, general_government_...
# #### Chart artifacts
# _Missing zscore_heatmap: /workspaces/da-ai-v2/bs2026_student_projects/Arturas_Sotnicenko_v2/outputs_baltics_v2/EE/charts/zscore_normalization_heatmap.png_
# _Missing zscore_timelines: /workspaces/da-ai-v2/bs2026_student_projects/Arturas_Sotnicenko_v2/outputs_baltics_v2/EE/charts/zscore_normalization_timelines.png_

# %% [markdown]
# ## Inflation rolling override example
#
# This mirrors the legacy inflation-specific override pattern while keeping the `v2` request typed at the adapter boundary.

# %%
inflation_rolling_override_config = {
    "mode": "static_baseline",
    "baseline_start_year": 1990,
    "limit_to_baseline_window": True,
    "min_obs_for_zscore": 3,
    "indicator_overrides": {
        "inflation_cpi_yoy": {
            "mode": "rolling_trailing",
            "rolling_window_years": 3,
            "exclude_current_from_window": True,
            "min_obs_for_zscore": 3,
        }
    },
}

_lt_inflation_override_view = _render_country_normalized_section(
    "LT",
    normalization_config=inflation_rolling_override_config,
    region_label=f"{normalized_region_label}_inflation_override",
    force_refresh=True,
    show_labels=True,
)
# Out:
# ### Lithuania
# - Render: Lithuania | dynamic notebook | region Baltics_v2_inflation_override
# - Normalization: Static baseline from 1990, min obs 3 | 1 indicator override
# - Transformation: No transformation requested.
#   country_code country_display_name     render_origin  \
# 0           LT            Lithuania  dynamic_notebook
#
#                     region_label  \
# 0  Baltics_v2_inflation_override
#
#                                        normalization  \
# 0  Static baseline from 1990, min obs 3 | 1 indic...
#
#                  transformation  \
# 0  No transformation requested.
#
#                                        manifest_path  \
# 0  /workspaces/da-ai-v2/bs2026_student_projects/A...
#
#                                       anomalies_path
# 0  /workspaces/da-ai-v2/bs2026_student_projects/A...
# #### Indicator sections
#              group_name                                      indicator_ids
# 0     Fiscal indicators              general_government_gross_debt_pct_gdp
# 1  Inflation and prices                                  inflation_cpi_yoy
# 2     Output and growth          real_gdp, gdp_current_usd, gdp_per_capita
# 3             Remaining  exchange_rate_lcu_per_usd, general_government_...
# #### Render manifest
#          chart_type status                                          file_path  \
# 0    zscore_heatmap     ok  /workspaces/da-ai-v2/bs2026_student_projects/A...
# 1  zscore_timelines     ok  /workspaces/da-ai-v2/bs2026_student_projects/A...
#
#       render_origin                   region_label normalization_mode  \
# 0  dynamic_notebook  Baltics_v2_inflation_override    static_baseline
# 1  dynamic_notebook  Baltics_v2_inflation_override    static_baseline
#
#                                          config_slug  \
# 0  mode_static_baseline__baseline_1990__limit_1__...
# 1  mode_static_baseline__baseline_1990__limit_1__...
#
#   transformation_strategy_slug
# 0
# 1
# #### Chart labels
#                                  indicator_id  \
# 0                   exchange_rate_lcu_per_usd
# 1                             gdp_current_usd
# 2                              gdp_per_capita
# 3  general_government_balance_deficit_pct_gdp
# 4       general_government_gross_debt_pct_gdp
# 5                           inflation_cpi_yoy
# 6                       lending_interest_rate
# 7                                    real_gdp
# 8                       trade_balance_pct_gdp
# 9                           unemployment_rate
#
#                       indicator_label source_label  \
# 0                       Exchange rate   World Bank
# 1                         Nominal GDP   World Bank
# 2                      GDP per capita   World Bank
# 3  General government balance/deficit     Eurostat
# 4       General government gross debt     Eurostat
# 5                           Inflation   World Bank
# 6                       Interest rate     Eurostat
# 7                            Real GDP   World Bank
# 8                       Trade balance   World Bank
# 9                   Unemployment rate   World Bank
#
#                           indicator_source_label
# 0                     Exchange rate | World Bank
# 1                       Nominal GDP | World Bank
# 2                    GDP per capita | World Bank
# 3  General government balance/deficit | Eurostat
# 4       General government gross debt | Eurostat
# 5                         Inflation | World Bank
# 6                       Interest rate | Eurostat
# 7                          Real GDP | World Bank
# 8                     Trade balance | World Bank
# 9                 Unemployment rate | World Bank
# #### Chart artifacts
